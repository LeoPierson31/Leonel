# %%
import yfinance as yf
import pandas as pd
import xlwings as xw
import numpy as np
import datetime as dt
from datetime import datetime
import matplotlib.pyplot as plt
from pandas_datareader import data 

import yfinance as yfin
import statistics
import seaborn as sns

# %%
assets = ['^MXX','WALMEX.MX','FEMSAUBD.MX','ALFAA.MX','CEMEXCPO.MX','BIMBOA.MX','GFNORTEO.MX','SORIANAB.MX','ALPEKA.MX','GCARSOA1.MX','LIVEPOL1.MX','ELEKTRA.MX','PE&OLES.MX','GFINBURO.MX','GRUMAB.MX','BACHOCOB.MX','ICA.MX','CULTIBAB.MX','GNP.MX','FRAGUAB.MX','KIMBERA.MX','SIMECB.MX','ALSEA.MX','GPH1.MX','VITROA.MX','GENTERA.MX','HERDEZ.MX','VOLARA.MX','LABB.MX','MEGACPO.MX','BEVIDESA.MX','AXTELCPO.MX','GCC.MX','GISSAA.MX','CMOCTEZ.MX','BAFARB.MX','GPROFUT.MX','LAMOSA.MX','CABLECPO.MX','CERAMICB.MX','PINFRA.MX','AGUA.MX','CIEB.MX','ARA.MX','POCHTECB.MX','ASURB.MX','FINDEP.MX','POSADASA.MX','MINSAB.MX','GAPB.MX','INVEXA.MX','MONEXB.MX','COLLADO.MX','AUTLANB.MX','PASAB.MX']
yfin.pdr_override()
stocks = data.get_data_yahoo(assets, start='2019-09-14', end='2023-11-18')
# Out:
# [*********************100%%**********************]  55 of 55 completed

# %%
df2=pd.read_excel("SECTORES.xlsx") #leemos nuestra base de datos
df2['SCTR']=df2['SCTR'].astype(int)

# %%
stocks.head(8)
stocks1=stocks['Adj Close']

# %%
stocks1.head
retornos = np.log(stocks1).diff()
retornos = retornos.dropna()
retornos
# Out:
# C:\ProgramData\anaconda3\Lib\site-packages\pandas\core\internals\blocks.py:329: RuntimeWarning: invalid value encountered in log
#   result = func(self.values, **kwargs)
#              AGUA.MX  ALFAA.MX  ALPEKA.MX  ALSEA.MX    ARA.MX  ASURB.MX  \
# Date
# 2022-01-12  0.016345  0.020869   0.012497 -0.011780  0.004598  0.005289
# 2022-01-13 -0.018219 -0.012065   0.003673  0.000232  0.015927  0.006123
# 2022-01-14  0.009337 -0.002025   0.003660 -0.007227 -0.006795  0.019840
# 2022-01-19  0.023189  0.023209   0.085963 -0.033559 -0.018141 -0.042153
# 2022-01-20  0.004645  0.004040  -0.008271  0.001431 -0.025494  0.000809
# ...              ...       ...        ...       ...       ...       ...
# 2023-11-13  0.023679  0.013328   0.006873  0.001147  0.000000  0.001270
# 2023-11-14  0.025985  0.007912   0.000000  0.001309  0.009245  0.004960
# 2023-11-15 -0.003926  0.017362   0.017352  0.011867 -0.018576  0.008877
# 2023-11-16 -0.036792  0.006861  -0.012797 -0.027192  0.009331 -0.001687
# 2023-11-17  0.005919  0.000854  -0.016807  0.002488  0.000000  0.016671
#
#             AUTLANB.MX  AXTELCPO.MX  BACHOCOB.MX  BAFARB.MX  ...  PE&OLES.MX  \
# Date                                                         ...
# 2022-01-12    0.000000     0.079022     0.014054   0.000000  ...    0.042392
# 2022-01-13    0.029559     0.036105     0.004274   0.000000  ...    0.001659
# 2022-01-14    0.000746    -0.026349    -0.003722   0.000000  ...   -0.037447
# 2022-01-19    0.009720     0.000000    -0.003818   0.000000  ...    0.015172
# 2022-01-20   -0.001489     0.019657    -0.001504   0.000000  ...    0.000293
# ...                ...          ...          ...        ...  ...         ...
# 2023-11-13   -0.004819    -0.018088     0.000000   0.000000  ...   -0.011320
# 2023-11-14   -0.005814    -0.014445     0.000000  -0.071096  ...    0.047160
# 2023-11-15    0.005814     0.014445     0.000000   0.000000  ...    0.023456
# 2023-11-16    0.019139     0.000000     0.000000   0.000000  ...   -0.019610
# 2023-11-17   -0.004751    -0.023748     0.000000   0.000000  ...    0.024176
#
#             PINFRA.MX  POCHTECB.MX  POSADASA.MX  SIMECB.MX  SORIANAB.MX  \
# Date
# 2022-01-12   0.023221     0.000000     0.000000   0.005634    -0.017752
# 2022-01-13  -0.016242     0.000000    -0.004955   0.033207     0.024016
# 2022-01-14  -0.010231     0.000000     0.003306  -0.022033    -0.001667
# 2022-01-19  -0.008098    -0.028988    -0.021564  -0.019694    -0.008361
# 2022-01-20  -0.004337     0.028988     0.000000   0.019638    -0.030693
# ...               ...          ...          ...        ...          ...
# 2023-11-13  -0.017788     0.000000     0.000000  -0.000051     0.016868
# 2023-11-14   0.011955     0.000000     0.000000   0.000051    -0.019206
# 2023-11-15   0.056269     0.000000     0.000000  -0.005115     0.019534
# 2023-11-16  -0.022724     0.000000     0.000000  -0.010309    -0.002626
# 2023-11-17   0.005167     0.000000     0.000000   0.025577     0.002298
#
#             VITROA.MX  VOLARA.MX  WALMEX.MX      ^MXX
# Date
# 2022-01-12   0.000000   0.007682   0.006207  0.016619
# 2022-01-13  -0.006501   0.011414  -0.012174 -0.000384
# 2022-01-14  -0.004357   0.001512  -0.005443 -0.003446
# 2022-01-19   0.000000  -0.035519   0.002955 -0.007712
# 2022-01-20  -0.004396  -0.022689  -0.010454 -0.005979
# ...               ...        ...        ...       ...
# 2023-11-13   0.002255  -0.038466  -0.013648 -0.003270
# 2023-11-14  -0.103860   0.058920   0.049495  0.027423
# 2023-11-15   0.002496   0.016587  -0.011710  0.005415
# 2023-11-16  -0.002995  -0.001733  -0.011848 -0.006215
# 2023-11-17   0.000000   0.016344   0.004991  0.004103
#
# [425 rows x 55 columns]

# %%
acumulado = (1+retornos).cumprod()
acumulado.fillna(1, inplace = True)
acumulado
# Out:
#              AGUA.MX  ALFAA.MX  ALPEKA.MX  ALSEA.MX    ARA.MX  ASURB.MX  \
# Date
# 2022-01-12  1.016345  1.020869   1.012497  0.988220  1.004598  1.005289
# 2022-01-13  0.997828  1.008553   1.016216  0.988450  1.020598  1.011444
# 2022-01-14  1.007145  1.006511   1.019935  0.981306  1.013663  1.031511
# 2022-01-19  1.030500  1.029871   1.107612  0.948374  0.995275  0.988030
# 2022-01-20  1.035287  1.034032   1.098451  0.949731  0.969901  0.988829
# ...              ...       ...        ...       ...       ...       ...
# 2023-11-13  0.899104  0.602241   0.527629  1.297136  0.698162  0.966927
# 2023-11-14  0.922467  0.607006   0.527629  1.298835  0.704616  0.971723
# 2023-11-15  0.918845  0.617545   0.536785  1.314248  0.691527  0.980349
# 2023-11-16  0.885039  0.621782   0.529916  1.278510  0.697980  0.978695
# 2023-11-17  0.890278  0.622313   0.521010  1.281691  0.697980  0.995011
#
#             AUTLANB.MX  AXTELCPO.MX  BACHOCOB.MX  BAFARB.MX  ...  PE&OLES.MX  \
# Date                                                         ...
# 2022-01-12    1.000000     1.079022     1.014054   1.000000  ...    1.042392
# 2022-01-13    1.029559     1.117980     1.018389   1.000000  ...    1.044121
# 2022-01-14    1.030327     1.088523     1.014599   1.000000  ...    1.005022
# 2022-01-19    1.040342     1.088523     1.010725   1.000000  ...    1.020270
# 2022-01-20    1.038793     1.109919     1.009205   1.000000  ...    1.020569
# ...                ...          ...          ...        ...  ...         ...
# 2023-11-13    0.795940     0.206525     0.823197   1.431936  ...    0.631466
# 2023-11-14    0.791312     0.203542     0.823197   1.330131  ...    0.661246
# 2023-11-15    0.795913     0.206482     0.823197   1.330131  ...    0.676756
# 2023-11-16    0.811146     0.206482     0.823197   1.330131  ...    0.663485
# 2023-11-17    0.807293     0.201579     0.823197   1.330131  ...    0.679525
#
#             PINFRA.MX  POCHTECB.MX  POSADASA.MX  SIMECB.MX  SORIANAB.MX  \
# Date
# 2022-01-12   1.023221     1.000000     1.000000   1.005634     0.982248
# 2022-01-13   1.006602     1.000000     0.995045   1.039027     1.005838
# 2022-01-14   0.996303     1.000000     0.998335   1.016134     1.004162
# 2022-01-19   0.988235     0.971012     0.976807   0.996123     0.995766
# 2022-01-20   0.983948     0.999160     0.976807   1.015685     0.965203
# ...               ...          ...          ...        ...          ...
# 2023-11-13   1.058551     1.103281     0.841848   1.019027     1.049304
# 2023-11-14   1.071206     1.103281     0.841848   1.019079     1.029151
# 2023-11-15   1.131482     1.103281     0.841848   1.013866     1.049255
# 2023-11-16   1.105770     1.103281     0.841848   1.003414     1.046499
# 2023-11-17   1.111483     1.103281     0.841848   1.029078     1.048904
#
#             VITROA.MX  VOLARA.MX  WALMEX.MX      ^MXX
# Date
# 2022-01-12   1.000000   1.007682   1.006207  1.016619
# 2022-01-13   0.993499   1.019184   0.993957  1.016229
# 2022-01-14   0.989170   1.020725   0.988548  1.012727
# 2022-01-19   0.989170   0.984470   0.991469  1.004917
# 2022-01-20   0.984823   0.962134   0.981105  0.998909
# ...               ...        ...        ...       ...
# 2023-11-13   1.002830   0.261098   0.855812  0.960587
# 2023-11-14   0.898676   0.276482   0.898170  0.986929
# 2023-11-15   0.900919   0.281068   0.887653  0.992273
# 2023-11-16   0.898220   0.280581   0.877136  0.986106
# 2023-11-17   0.898220   0.285167   0.881513  0.990152
#
# [425 rows x 55 columns]

# %%
acumulado.plot()
plt.show()

# %%
Anualizado = acumulado[1:]**(252/len(acumulado))-1

# %%
REND=Anualizado.mean()

# %%
VOL=Anualizado.std()

# %%
REND_VOL=REND/VOL
REND_VOL
# Out:
# AGUA.MX       -0.858993
# ALFAA.MX      -1.901842
# ALPEKA.MX      0.101756
# ALSEA.MX       0.420802
# ARA.MX        -2.459921
# ASURB.MX       0.861953
# AUTLANB.MX     0.797756
# AXTELCPO.MX   -2.619692
# BACHOCOB.MX   -0.005362
# BAFARB.MX      0.056392
# BEVIDESA.MX         NaN
# BIMBOA.MX      0.805790
# CABLECPO.MX         NaN
# CEMEXCPO.MX   -1.507875
# CERAMICB.MX    1.585994
# CIEB.MX        0.908334
# CMOCTEZ.MX    -0.176091
# COLLADO.MX     3.042834
# CULTIBAB.MX   -0.904585
# ELEKTRA.MX    -2.766733
# FEMSAUBD.MX    0.103231
# FINDEP.MX     -0.284273
# FRAGUAB.MX     0.765466
# GAPB.MX        0.530319
# GCARSOA1.MX    1.056874
# GCC.MX        -0.407189
# GENTERA.MX     1.715769
# GFINBURO.MX    2.163348
# GFNORTEO.MX    0.543208
# GISSAA.MX      1.161323
# GNP.MX         0.458645
# GPH1.MX        0.745724
# GPROFUT.MX     0.860257
# GRUMAB.MX     -0.131007
# HERDEZ.MX      0.442711
# ICA.MX        -1.124451
# INVEXA.MX      0.794022
# KIMBERA.MX    -0.430604
# LABB.MX       -0.688742
# LAMOSA.MX      0.494784
# LIVEPOL1.MX    2.444131
# MEGACPO.MX    -1.996364
# MINSAB.MX      0.764090
# MONEXB.MX      1.722792
# PASAB.MX       0.543320
# PE&OLES.MX    -1.063875
# PINFRA.MX      0.286070
# POCHTECB.MX    1.895897
# POSADASA.MX   -1.722929
# SIMECB.MX      1.836619
# SORIANAB.MX    0.122061
# VITROA.MX     -1.279575
# VOLARA.MX     -2.252082
# WALMEX.MX     -0.998361
# ^MXX          -0.495537
# dtype: float64

# %%
beta=Anualizado.cov().div(Anualizado.var())

# %%
beta.mean()
# Out:
# AGUA.MX        0.120758
# ALFAA.MX      -0.228772
# ALPEKA.MX     -0.159204
# ALSEA.MX       0.263831
# ARA.MX         0.142939
# ASURB.MX       0.307064
# AUTLANB.MX    -0.186194
# AXTELCPO.MX   -0.086148
# BACHOCOB.MX   -0.191368
# BAFARB.MX      0.166562
# BEVIDESA.MX         NaN
# BIMBOA.MX      0.281407
# CABLECPO.MX         NaN
# CEMEXCPO.MX    0.248845
# CERAMICB.MX    0.290742
# CIEB.MX        0.119242
# CMOCTEZ.MX     0.042581
# COLLADO.MX     0.255249
# CULTIBAB.MX    0.364924
# ELEKTRA.MX    -0.127077
# FEMSAUBD.MX    0.278005
# FINDEP.MX     -0.856666
# FRAGUAB.MX     0.179264
# GAPB.MX        0.300299
# GCARSOA1.MX    0.234725
# GCC.MX         0.401678
# GENTERA.MX     0.175007
# GFINBURO.MX    0.300293
# GFNORTEO.MX    0.353677
# GISSAA.MX      0.309601
# GNP.MX         0.484622
# GPH1.MX        1.447393
# GPROFUT.MX     0.369065
# GRUMAB.MX      0.470529
# HERDEZ.MX      0.229880
# ICA.MX        -9.372920
# INVEXA.MX      1.530418
# KIMBERA.MX     0.404346
# LABB.MX       -0.145858
# LAMOSA.MX      0.416840
# LIVEPOL1.MX    0.287751
# MEGACPO.MX    -0.239318
# MINSAB.MX      0.655408
# MONEXB.MX      0.226343
# PASAB.MX       0.084322
# PE&OLES.MX     0.000811
# PINFRA.MX      0.451593
# POCHTECB.MX   -0.048369
# POSADASA.MX   -0.514560
# SIMECB.MX     -0.283829
# SORIANAB.MX    0.305795
# VITROA.MX     -0.213195
# VOLARA.MX      0.011093
# WALMEX.MX     -0.327489
# ^MXX           0.812140
# dtype: float64

# %%
cov = retornos.cov()*252
cov_with_market = cov.iloc[0,1]
market_var = retornos.var()*252
stock_beta = cov_with_market / market_var

# %%
tasalibredriesgo = 0.0095
riskpremium = (retornos['^MXX'].mean()*252) - tasalibredriesgo

# %%
stock_capm_return = tasalibredriesgo + stock_beta * riskpremium

# %%
sharpe_stock = (stock_capm_return - tasalibredriesgo) /(Anualizado.std()*252**0.5)

# %%
BETAS=(round(stock_beta,3))

# %%
CAPM=round(stock_capm_return*100,3)
CAPM
# Out:
# AGUA.MX          0.914
# ALFAA.MX         0.868
# ALPEKA.MX        0.886
# ALSEA.MX         0.872
# ARA.MX           0.869
# ASURB.MX         0.873
# AUTLANB.MX       0.803
# AXTELCPO.MX      0.926
# BACHOCOB.MX      0.845
# BAFARB.MX        0.861
# BEVIDESA.MX       -inf
# BIMBOA.MX        0.880
# CABLECPO.MX       -inf
# CEMEXCPO.MX      0.901
# CERAMICB.MX      0.463
# CIEB.MX          0.921
# CMOCTEZ.MX       0.483
# COLLADO.MX       0.318
# CULTIBAB.MX      0.869
# ELEKTRA.MX       0.797
# FEMSAUBD.MX      0.813
# FINDEP.MX        0.405
# FRAGUAB.MX       0.841
# GAPB.MX          0.902
# GCARSOA1.MX      0.888
# GCC.MX           0.863
# GENTERA.MX       0.894
# GFINBURO.MX      0.887
# GFNORTEO.MX      0.884
# GISSAA.MX        0.871
# GNP.MX           0.320
# GPH1.MX         -0.733
# GPROFUT.MX       0.663
# GRUMAB.MX        0.861
# HERDEZ.MX        0.892
# ICA.MX        -107.533
# INVEXA.MX        0.294
# KIMBERA.MX       0.865
# LABB.MX          0.877
# LAMOSA.MX        0.778
# LIVEPOL1.MX      0.769
# MEGACPO.MX       0.862
# MINSAB.MX        0.386
# MONEXB.MX        0.895
# PASAB.MX         0.820
# PE&OLES.MX       0.920
# PINFRA.MX        0.842
# POCHTECB.MX      0.773
# POSADASA.MX      0.694
# SIMECB.MX        0.834
# SORIANAB.MX      0.864
# VITROA.MX        0.817
# VOLARA.MX        0.927
# WALMEX.MX        0.840
# ^MXX             0.665
# dtype: float64

# %%
SHARP=round(sharpe_stock,3)
SHARP
# Out:
# AGUA.MX        -0.001
# ALFAA.MX       -0.001
# ALPEKA.MX      -0.000
# ALSEA.MX       -0.000
# ARA.MX         -0.001
# ASURB.MX       -0.001
# AUTLANB.MX     -0.001
# AXTELCPO.MX    -0.000
# BACHOCOB.MX    -0.001
# BAFARB.MX      -0.000
# BEVIDESA.MX      -inf
# BIMBOA.MX      -0.000
# CABLECPO.MX      -inf
# CEMEXCPO.MX    -0.000
# CERAMICB.MX    -0.004
# CIEB.MX        -0.000
# CMOCTEZ.MX     -0.012
# COLLADO.MX     -0.022
# CULTIBAB.MX    -0.001
# ELEKTRA.MX     -0.002
# FEMSAUBD.MX    -0.001
# FINDEP.MX      -0.023
# FRAGUAB.MX     -0.000
# GAPB.MX        -0.000
# GCARSOA1.MX    -0.000
# GCC.MX         -0.001
# GENTERA.MX     -0.000
# GFINBURO.MX    -0.001
# GFNORTEO.MX    -0.001
# GISSAA.MX      -0.001
# GNP.MX         -0.008
# GPH1.MX        -0.062
# GPROFUT.MX     -0.004
# GRUMAB.MX      -0.001
# HERDEZ.MX      -0.000
# ICA.MX        -22.118
# INVEXA.MX      -0.025
# KIMBERA.MX     -0.001
# LABB.MX        -0.001
# LAMOSA.MX      -0.004
# LIVEPOL1.MX    -0.003
# MEGACPO.MX     -0.001
# MINSAB.MX      -0.009
# MONEXB.MX      -0.000
# PASAB.MX       -0.000
# PE&OLES.MX     -0.000
# PINFRA.MX      -0.001
# POCHTECB.MX    -0.002
# POSADASA.MX    -0.004
# SIMECB.MX      -0.002
# SORIANAB.MX    -0.001
# VITROA.MX      -0.002
# VOLARA.MX      -0.000
# WALMEX.MX      -0.002
# ^MXX           -0.005
# dtype: float64

# %%
datos=[REND,VOL,REND_VOL,BETAS,CAPM,SHARP]
col=['REND','VOL','REND_VOL','BETAS','CAPM','SHARP']

# %%
DF = pd.DataFrame(datos,index=col)
DF
# Out:
#            AGUA.MX  ALFAA.MX  ALPEKA.MX  ALSEA.MX    ARA.MX  ASURB.MX  \
# REND     -0.034539 -0.166701   0.014616  0.043041 -0.106088  0.066505
# VOL       0.040209  0.087652   0.143638  0.102282  0.043127  0.077156
# REND_VOL -0.858993 -1.901842   0.101756  0.420802 -2.459921  0.861953
# BETAS     0.116000  0.267000   0.208000  0.254000  0.263000  0.251000
# CAPM      0.914000  0.868000   0.886000  0.872000  0.869000  0.873000
# SHARP    -0.001000 -0.001000  -0.000000 -0.000000 -0.001000 -0.001000
#
#           AUTLANB.MX  AXTELCPO.MX  BACHOCOB.MX  BAFARB.MX  ...  PE&OLES.MX  \
# REND        0.066617    -0.425281    -0.000239   0.010372  ...   -0.096941
# VOL         0.083505     0.162340     0.044620   0.183927  ...    0.091120
# REND_VOL    0.797756    -2.619692    -0.005362   0.056392  ...   -1.063875
# BETAS       0.479000     0.077000     0.344000   0.291000  ...    0.097000
# CAPM        0.803000     0.926000     0.845000   0.861000  ...    0.920000
# SHARP      -0.001000    -0.000000    -0.001000  -0.000000  ...   -0.000000
#
#           PINFRA.MX  POCHTECB.MX  POSADASA.MX  SIMECB.MX  SORIANAB.MX  \
# REND       0.019951     0.095271    -0.064596   0.072399     0.008617
# VOL        0.069743     0.050251     0.037492   0.039420     0.070600
# REND_VOL   0.286070     1.895897    -1.722929   1.836619     0.122061
# BETAS      0.351000     0.578000     0.836000   0.378000     0.281000
# CAPM       0.842000     0.773000     0.694000   0.834000     0.864000
# SHARP     -0.001000    -0.002000    -0.004000  -0.002000    -0.001000
#
#           VITROA.MX  VOLARA.MX  WALMEX.MX      ^MXX
# REND      -0.070514  -0.303103  -0.031714 -0.018219
# VOL        0.055107   0.134588   0.031766  0.036766
# REND_VOL  -1.279575  -2.252082  -0.998361 -0.495537
# BETAS      0.434000   0.076000   0.357000  0.930000
# CAPM       0.817000   0.927000   0.840000  0.665000
# SHARP     -0.002000  -0.000000  -0.002000 -0.005000
#
# [6 rows x 55 columns]

# %%
DF1 = DF.T
DF1
DF1.index.name = 'ACTIVOS'
DF1

DF1=DF1.merge(df2, left_on=['ACTIVOS'], right_on=['ACTIVO'])
DF1=DF1.drop(columns=['SECTOR'])
DF1 = DF1.set_index('ACTIVO')
Filt=(DF1['REND']>0)
DF1=DF1.loc[Filt,['REND','VOL','REND_VOL','BETAS','CAPM','SHARP','SCTR']]
DF1
# Out:
#                  REND       VOL  REND_VOL  BETAS   CAPM  SHARP  SCTR
# ACTIVO
# ALPEKA.MX    0.014616  0.143638  0.101756  0.208  0.886 -0.000     3
# ALSEA.MX     0.043041  0.102282  0.420802  0.254  0.872 -0.000     1
# ASURB.MX     0.066505  0.077156  0.861953  0.251  0.873 -0.001     2
# AUTLANB.MX   0.066617  0.083505  0.797756  0.479  0.803 -0.001     3
# BAFARB.MX    0.010372  0.183927  0.056392  0.291  0.861 -0.000     1
# BIMBOA.MX    0.080242  0.099582  0.805790  0.227  0.880 -0.000     1
# CERAMICB.MX  0.130417  0.082231  1.585994  1.586  0.463 -0.004     3
# CIEB.MX      0.215947  0.237740  0.908334  0.094  0.921 -0.000     1
# COLLADO.MX   0.054408  0.017881  3.042834  2.059  0.318 -0.022     3
# FEMSAUBD.MX  0.011452  0.110937  0.103231  0.447  0.813 -0.001     1
# FRAGUAB.MX   0.121645  0.158916  0.765466  0.357  0.841 -0.000     5
# GAPB.MX      0.040995  0.077303  0.530319  0.158  0.902 -0.000     2
# GCARSOA1.MX  0.126599  0.119786  1.056874  0.201  0.888 -0.000     2
# GENTERA.MX   0.281411  0.164014  1.715769  0.183  0.894 -0.000     4
# GFINBURO.MX  0.156888  0.072521  2.163348  0.206  0.887 -0.001     4
# GFNORTEO.MX  0.044022  0.081041  0.543208  0.216  0.884 -0.001     4
# GISSAA.MX    0.077187  0.066464  1.161323  0.259  0.871 -0.001     2
# GNP.MX       0.022188  0.048378  0.458645  2.055  0.320 -0.008     4
# GPH1.MX      0.012768  0.017122  0.745724  5.486 -0.733 -0.062     1
# GPROFUT.MX   0.044140  0.051311  0.860257  0.934  0.663 -0.004     1
# HERDEZ.MX    0.054243  0.122524  0.442711  0.189  0.892 -0.000     1
# INVEXA.MX    0.013240  0.016675  0.794022  2.140  0.294 -0.025     4
# LAMOSA.MX    0.012021  0.024296  0.494784  0.562  0.778 -0.004     3
# LIVEPOL1.MX  0.105453  0.043145  2.444131  0.589  0.769 -0.003     1
# MINSAB.MX    0.031428  0.041131  0.764090  1.837  0.386 -0.009     1
# MONEXB.MX    0.168678  0.097910  1.722792  0.180  0.895 -0.000     4
# PASAB.MX     0.132681  0.244203  0.543320  0.424  0.820 -0.000     2
# PINFRA.MX    0.019951  0.069743  0.286070  0.351  0.842 -0.001     2
# POCHTECB.MX  0.095271  0.050251  1.895897  0.578  0.773 -0.002     3
# SIMECB.MX    0.072399  0.039420  1.836619  0.378  0.834 -0.002     3
# SORIANAB.MX  0.008617  0.070600  0.122061  0.281  0.864 -0.001     1

# %%
DF1.dtypes
# Out:
# REND        float64
# VOL         float64
# REND_VOL    float64
# BETAS       float64
# CAPM        float64
# SHARP       float64
# SCTR          int32
# dtype: object

# %%
newdf2=pd.get_dummies(data=DF1, drop_first=True)
newdf2
# Out:
#                  REND       VOL  REND_VOL  BETAS   CAPM  SHARP  SCTR
# ACTIVO
# ALPEKA.MX    0.014616  0.143638  0.101756  0.208  0.886 -0.000     3
# ALSEA.MX     0.043041  0.102282  0.420802  0.254  0.872 -0.000     1
# ASURB.MX     0.066505  0.077156  0.861953  0.251  0.873 -0.001     2
# AUTLANB.MX   0.066617  0.083505  0.797756  0.479  0.803 -0.001     3
# BAFARB.MX    0.010372  0.183927  0.056392  0.291  0.861 -0.000     1
# BIMBOA.MX    0.080242  0.099582  0.805790  0.227  0.880 -0.000     1
# CERAMICB.MX  0.130417  0.082231  1.585994  1.586  0.463 -0.004     3
# CIEB.MX      0.215947  0.237740  0.908334  0.094  0.921 -0.000     1
# COLLADO.MX   0.054408  0.017881  3.042834  2.059  0.318 -0.022     3
# FEMSAUBD.MX  0.011452  0.110937  0.103231  0.447  0.813 -0.001     1
# FRAGUAB.MX   0.121645  0.158916  0.765466  0.357  0.841 -0.000     5
# GAPB.MX      0.040995  0.077303  0.530319  0.158  0.902 -0.000     2
# GCARSOA1.MX  0.126599  0.119786  1.056874  0.201  0.888 -0.000     2
# GENTERA.MX   0.281411  0.164014  1.715769  0.183  0.894 -0.000     4
# GFINBURO.MX  0.156888  0.072521  2.163348  0.206  0.887 -0.001     4
# GFNORTEO.MX  0.044022  0.081041  0.543208  0.216  0.884 -0.001     4
# GISSAA.MX    0.077187  0.066464  1.161323  0.259  0.871 -0.001     2
# GNP.MX       0.022188  0.048378  0.458645  2.055  0.320 -0.008     4
# GPH1.MX      0.012768  0.017122  0.745724  5.486 -0.733 -0.062     1
# GPROFUT.MX   0.044140  0.051311  0.860257  0.934  0.663 -0.004     1
# HERDEZ.MX    0.054243  0.122524  0.442711  0.189  0.892 -0.000     1
# INVEXA.MX    0.013240  0.016675  0.794022  2.140  0.294 -0.025     4
# LAMOSA.MX    0.012021  0.024296  0.494784  0.562  0.778 -0.004     3
# LIVEPOL1.MX  0.105453  0.043145  2.444131  0.589  0.769 -0.003     1
# MINSAB.MX    0.031428  0.041131  0.764090  1.837  0.386 -0.009     1
# MONEXB.MX    0.168678  0.097910  1.722792  0.180  0.895 -0.000     4
# PASAB.MX     0.132681  0.244203  0.543320  0.424  0.820 -0.000     2
# PINFRA.MX    0.019951  0.069743  0.286070  0.351  0.842 -0.001     2
# POCHTECB.MX  0.095271  0.050251  1.895897  0.578  0.773 -0.002     3
# SIMECB.MX    0.072399  0.039420  1.836619  0.378  0.834 -0.002     3
# SORIANAB.MX  0.008617  0.070600  0.122061  0.281  0.864 -0.001     1

# %%
newdf3 = newdf2.drop(columns=['VOL','REND_VOL','CAPM','SHARP'])

# %%
import matplotlib.pyplot as plt

# Preprocesado y modelado
# ------------------------------------------------------------------------------
from sklearn.datasets import fetch_california_housing
housing = fetch_california_housing()
from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeRegressor
from sklearn.tree import plot_tree
from sklearn.tree import export_graphviz
from sklearn.tree import export_text
from sklearn.model_selection import GridSearchCV
from sklearn.metrics import mean_squared_error
from sklearn.linear_model import LinearRegression
from sklearn import datasets
# Configuración warnings
# ------------------------------------------------------------------------------
import warnings
warnings.filterwarnings('once')

# %%
explicativas=DF1[['VOL','CAPM','SCTR']]

Objetivo=DF1[['REND']]
Objetivo
# Out:
#                  REND
# ACTIVO
# ALPEKA.MX    0.014616
# ALSEA.MX     0.043041
# ASURB.MX     0.066505
# AUTLANB.MX   0.066617
# BAFARB.MX    0.010372
# BIMBOA.MX    0.080242
# CERAMICB.MX  0.130417
# CIEB.MX      0.215947
# COLLADO.MX   0.054408
# FEMSAUBD.MX  0.011452
# FRAGUAB.MX   0.121645
# GAPB.MX      0.040995
# GCARSOA1.MX  0.126599
# GENTERA.MX   0.281411
# GFINBURO.MX  0.156888
# GFNORTEO.MX  0.044022
# GISSAA.MX    0.077187
# GNP.MX       0.022188
# GPH1.MX      0.012768
# GPROFUT.MX   0.044140
# HERDEZ.MX    0.054243
# INVEXA.MX    0.013240
# LAMOSA.MX    0.012021
# LIVEPOL1.MX  0.105453
# MINSAB.MX    0.031428
# MONEXB.MX    0.168678
# PASAB.MX     0.132681
# PINFRA.MX    0.019951
# POCHTECB.MX  0.095271
# SIMECB.MX    0.072399
# SORIANAB.MX  0.008617

# %%
#División de los datos en train y test
# ------------------------------------------------------------------------------

X = explicativas
y = Objetivo
regressor = DecisionTreeRegressor(random_state=0)
#Fit the regressor object to the dataset.
regressor.fit(X,y)
# Out:
# DecisionTreeRegressor(random_state=0)

# %%
# Splitting the dataset into training and testing set (80/20)
x_train, x_test, y_train, y_test = train_test_split(X, y, test_size = 0.2, random_state = 28)

# %%
# Initializing the Decision Tree Regression model
model = DecisionTreeRegressor(random_state = 0)

# Fitting the Decision Tree Regression model to the data
model.fit(x_train, y_train)
# Out:
# DecisionTreeRegressor(random_state=0)

# %%
# Predicting the target values of the test set
y_pred = model.predict(x_test)

# RMSE (Root Mean Square Error)
rmse = float(format(np.sqrt(mean_squared_error(y_test, y_pred)), '.3f'))
print("\nRMSE: ", rmse)
# Out:
# RMSE:  0.082

# %%
from sklearn.tree import plot_tree
plt.figure(figsize=(10,8), dpi=150)
plot_tree(model, feature_names=X.columns);

# %%
export_graphviz(model, out_file ='tree_structure.dot', 
               feature_names =['VOL','CAPM','SCTR'])

# %%
# Estructura del árbol creado
# ------------------------------------------------------------------------------
fig, ax = plt.subplots(figsize=(12, 5))

print(f"Profundidad del árbol: {model.get_depth()}")
print(f"Número de nodos terminales: {model.get_n_leaves()}")

plot = plot_tree(
            decision_tree = model,
            feature_names = explicativas.columns,
            class_names   = 'BETAS',
            filled        = True,
            impurity      = False,
            fontsize      = 10,
            precision     = 2,
            ax            = ax
       )
# Out:
# Profundidad del árbol: 9
# Número de nodos terminales: 24
# ---------------------------------------------------------------------------
# InvalidParameterError                     Traceback (most recent call last)
# Cell In[408], line 8
#       5 print(f"Profundidad del árbol: {model.get_depth()}")
#       6 print(f"Número de nodos terminales: {model.get_n_leaves()}")
# ----> 8 plot = plot_tree(
#       9             decision_tree = model,
#      10             feature_names = explicativas.columns,
#      11             class_names   = 'BETAS',
#      12             filled        = True,
#      13             impurity      = False,
#      14             fontsize      = 10,
#      15             precision     = 2,
#      16             ax            = ax
#      17        )
#
# File ~\AppData\Roaming\Python\Python311\site-packages\sklearn\utils\_param_validation.py:204, in validate_params.<locals>.decorator.<locals>.wrapper(*args, **kwargs)
#     201 to_ignore += ["self", "cls"]
#     202 params = {k: v for k, v in params.arguments.items() if k not in to_ignore}
# --> 204 validate_parameter_constraints(
#     205     parameter_constraints, params, caller_name=func.__qualname__
#     206 )
#     208 try:
#     209     with config_context(
#     210         skip_parameter_validation=(
#     211             prefer_skip_nested_validation or global_skip_validation
#     212         )
#     213     ):
#
# File ~\AppData\Roaming\Python\Python311\site-packages\sklearn\utils\_param_validation.py:96, in validate_parameter_constraints(parameter_constraints, params, caller_name)
#      90 else:
#      91     constraints_str = (
#      92         f"{', '.join([str(c) for c in constraints[:-1]])} or"
#      93         f" {constraints[-1]}"
#      94     )
# ---> 96 raise InvalidParameterError(
#      97     f"The {param_name!r} parameter of {caller_name} must be"
#      98     f" {constraints_str}. Got {param_val!r} instead."
#      99 )
#
# InvalidParameterError: The 'class_names' parameter of plot_tree must be an array-like, an instance of 'bool', an instance of 'numpy.bool_' or an instance of 'int' or None. Got 'BETAS' instead.

# %%
texto_model = export_text(
                    decision_tree = model,
                    feature_names = list(explicativas.columns)
               )
print(texto_model)

# %%
importancia_predictores = pd.DataFrame(
                            {'predictor': explicativas.columns,
                             'importancia': model.feature_importances_}
                            )
print("Importancia de los predictores en el modelo")
print("-------------------------------------------")
importancia_predictores.sort_values('importancia', ascending=False)

# %%
Filt=(DF1['CAPM']<=-.078)&(DF1['VOL']<=.09)&(DF1['SCTR']<=4) #Aplicamos un filtro a la base para descubirir la relacion de personas con diabetes y anemia
DF1.loc[Filt]

# %%
df_activos=retornos[['CMOCTEZ.MX','CULTIBAB.MX','PASAB.MX']]
df_activos
df_benchmark1 =  retornos[['^MXX']]

# %%
def pesosPortafolio(dataframe):
    array = []
    for i in dataframe.columns:
        array.append(1/len(dataframe.columns))
    arrayFinal = np.array(array)
    return arrayFinal
pesos = pesosPortafolio(df_activos)
pesos

# %%
from pypfopt.efficient_frontier import EfficientFrontier
from pypfopt import risk_models
from pypfopt import expected_returns

# %%
retornos1 = expected_returns.capm_return(df_activos, market_prices = df_benchmark1, returns_data= True, risk_free_rate=0.07/100, frequency=252)
retornos1
# Out:
# CMOCTEZ.MX     0.003423
# CULTIBAB.MX    0.002779
# PASAB.MX      -0.004118
# Name: mkt, dtype: float64

# %%
def pesosPortafolio(dataframe):
    array = []
    for i in dataframe.columns:
        array.append(1/len(dataframe.columns))
    arrayFinal = np.array(array)
    return arrayFinal
pesos = pesosPortafolio(df_activos)
pesos
# Out:
# array([0.33333333, 0.33333333, 0.33333333])

# %%
df_cov = df_activos.cov()*252
df_cov
# Out:
# ACTIVOS      CMOCTEZ.MX  CULTIBAB.MX  PASAB.MX
# ACTIVOS
# CMOCTEZ.MX     0.011637     0.000095  0.009083
# CULTIBAB.MX    0.000095     0.030292  0.003469
# PASAB.MX       0.009083     0.003469  0.019465

# %%
#Varianza del Portafolio
varianza_portafolio = pesos.T @ df_cov @pesos
"La varianza del portafolio es:" + " " + str(round(varianza_portafolio*100,1))+"%"
# Out:
# 'La varianza del portafolio es: 1.0%'

# %%
volatilidad_portafolio = np.sqrt(varianza_portafolio)
"La volatilidad del portafolio es:" + " " + str(round(volatilidad_portafolio*100,1))+"%"
# Out:
# 'La volatilidad del portafolio es: 9.8%'

# %%
retorno_portafolio = np.sum(pesos*retornos1)
'El retorno anual del portafolio es:' + ' ' + str(round(retorno_portafolio*100,3)) + '%'
# Out:
# 'El retorno anual del portafolio es: 0.069%'

# %%
ef = EfficientFrontier(retornos1, df_cov, weight_bounds=(-1,1))
weights = ef.min_volatility() 
cleaned_weights = ef.clean_weights() 
print(cleaned_weights) 
ef.portfolio_performance(verbose=True)
# Out:
# OrderedDict([('CMOCTEZ.MX', 0.65861), ('CULTIBAB.MX', 0.26579), ('PASAB.MX', 0.0756)])
# Expected annual return: 0.3%
# Annual volatility: 9.2%
# Sharpe Ratio: -0.19
# (0.00268193493128274, 0.09151956949308918, -0.1892279997014735)

# %%
ef = EfficientFrontier(retornos1, df_cov,weight_bounds=(0,1))
weights = ef.max_sharpe() 
cleaned_weights = ef.clean_weights() 
print(cleaned_weights) 
ef.portfolio_performance(verbose=True)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[416], line 2
#       1 ef = EfficientFrontier(retornos1, df_cov,weight_bounds=(0,1))
# ----> 2 weights = ef.max_sharpe()
#       3 cleaned_weights = ef.clean_weights()
#       4 print(cleaned_weights)
#
# File ~\AppData\Roaming\Python\Python311\site-packages\pypfopt\efficient_frontier\efficient_frontier.py:245, in EfficientFrontier.max_sharpe(self, risk_free_rate)
#     242     raise ValueError("risk_free_rate should be numeric")
#     244 if max(self.expected_returns) <= risk_free_rate:
# --> 245     raise ValueError(
#     246         "at least one of the assets must have an expected return exceeding the risk-free rate"
#     247     )
#     249 self._risk_free_rate = risk_free_rate
#     251 # max_sharpe requires us to make a variable transformation.
#     252 # Here we treat w as the transformed variable.
#
# ValueError: at least one of the assets must have an expected return exceeding the risk-free rate

# %%
from pypfopt.discrete_allocation import DiscreteAllocation, get_latest_prices
latest_prices = get_latest_prices(df_activos)
pesos = cleaned_weights 
da = DiscreteAllocation(pesos, latest_prices, total_portfolio_value=10000)
allocation, leftover = da.lp_portfolio()
print("Cantidad de acciones a comprar:", allocation)
print("Dinero sobrante: ${:.2f}".format(leftover))
# Out:
# Cantidad de acciones a comprar: {'CMOCTEZ.MX': 2803438, 'CULTIBAB.MX': 24240, 'PASAB.MX': 24240}
# Dinero sobrante: $10000.00

# %%
plt.figure(figsize=(12.2,4.5)) 
for i in df_activos.columns.values:
    plt.plot( df_activos[i],  label=i)
plt.title('Precio de las Acciones')
plt.xlabel('Fecha',fontsize=18)
plt.ylabel('Precio en USD',fontsize=18)
plt.legend(df_activos.columns.values, loc='upper left')
plt.savefig('plotprecios.png', dpi=300, bbox_inches='tight')
plt.show()

# %%
df = np.log(df_activos).diff()
df = df_activos.dropna()
df
# Out:
# C:\ProgramData\anaconda3\Lib\site-packages\pandas\core\internals\blocks.py:329: RuntimeWarning: divide by zero encountered in log
#   result = func(self.values, **kwargs)
# C:\ProgramData\anaconda3\Lib\site-packages\pandas\core\internals\blocks.py:329: RuntimeWarning: invalid value encountered in log
#   result = func(self.values, **kwargs)
# ACTIVOS     CMOCTEZ.MX  CULTIBAB.MX  PASAB.MX
# Date
# 2023-09-15    0.007435     0.000000  0.000000
# 2023-09-18    0.000000     0.000000  0.000000
# 2023-09-19    0.000000     0.000000  0.000000
# 2023-09-20    0.000000     0.000000  0.000000
# 2023-09-21    0.000000     0.000000  0.000000
# 2023-09-22    0.000000     0.000000  0.000000
# 2023-09-25    0.000000     0.000000  0.000000
# 2023-09-26   -0.007435     0.000000  0.000000
# 2023-09-27    0.000000     0.000000  0.000000
# 2023-09-28    0.000000     0.000000  0.000000
# 2023-09-29    0.000000     0.000000  0.000000
# 2023-10-02    0.000000     0.000000  0.000000
# 2023-10-03    0.000000     0.000000  0.000000
# 2023-10-04    0.000000     0.000000  0.000000
# 2023-10-05    0.000000     0.000000  0.000000
# 2023-10-06    0.000000     0.000000 -0.007025
# 2023-10-09    0.000000     0.000000  0.000000
# 2023-10-10    0.000000     0.000000  0.000000
# 2023-10-11    0.000000     0.000000  0.000000
# 2023-10-12    0.000000     0.000000  0.000000
# 2023-10-13    0.000000     0.000000  0.000000
# 2023-10-16    0.000000     0.000000  0.000000
# 2023-10-17    0.000000     0.000000  0.000000
# 2023-10-18    0.000000     0.000000  0.000000
# 2023-10-19    0.000000     0.000000  0.000000
# 2023-10-20    0.000000    -0.030827  0.000000
# 2023-10-23    0.000000     0.048527  0.000000
# 2023-10-24    0.000000     0.000000  0.000000
# 2023-10-25    0.000000     0.000000  0.000000
# 2023-10-26    0.000000     0.017392  0.033342
# 2023-10-27    0.000000     0.000000 -0.029656
# 2023-10-30    0.000000     0.000000  0.000000
# 2023-10-31    0.000000     0.000000  0.000000
# 2023-11-01    0.000000    -0.037774  0.000000
# 2023-11-06    0.000000     0.000000  0.000000
# 2023-11-07    0.000000     0.000000  0.000000
# 2023-11-08    0.000000    -0.011707  0.000000
# 2023-11-09    0.000000     0.000000  0.000000
# 2023-11-10    0.000000    -0.001813  0.000000
# 2023-11-13    0.043803     0.000000  0.036129
# 2023-11-14    0.000000     0.000000  0.000000
# 2023-11-15    0.000000     0.000000  0.000000
# 2023-11-16    0.000000     0.000000  0.000000
# 2023-11-17    0.000000     0.000000  0.000000

# %%
plt.figure(figsize=(12.2,4.5)) 
for i in df_activos.columns.values:
    plt.hist( df[i],  label=i, bins = 200)
plt.title('Histograma de los retornos')
plt.xlabel('Fecha',fontsize=18)
plt.ylabel('Precio en MXN',fontsize=18)
plt.legend(df.columns.values)
plt.savefig('plotretornosnormales.png', dpi=300, bbox_inches='tight')
plt.show()

# %%
import seaborn as sns
ef = EfficientFrontier(retornos1, df_cov, weight_bounds=(-1,1))
weights = ef.min_volatility() 
cleaned_weights = ef.clean_weights() 
print(cleaned_weights) 
ef.portfolio_performance(verbose=True)
# Out:
# OrderedDict([('CMOCTEZ.MX', 0.65861), ('CULTIBAB.MX', 0.26579), ('PASAB.MX', 0.0756)])
# Expected annual return: 0.3%
# Annual volatility: 9.2%
# Sharpe Ratio: -0.19
# (0.00268193493128274, 0.09151956949308918, -0.1892279997014735)

# %%
# Log of percentage change
cov_matrix = df_activos.pct_change().apply(lambda x: np.log(1+x)).cov()
cov_matrix
# Out:
# C:\ProgramData\anaconda3\Lib\site-packages\pandas\core\arraylike.py:396: RuntimeWarning: divide by zero encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# C:\ProgramData\anaconda3\Lib\site-packages\pandas\core\arraylike.py:396: RuntimeWarning: invalid value encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# ACTIVOS      CMOCTEZ.MX  CULTIBAB.MX  PASAB.MX
# ACTIVOS
# CMOCTEZ.MX          NaN          NaN       NaN
# CULTIBAB.MX         NaN          NaN       NaN
# PASAB.MX            NaN          NaN       NaN

# %%
corr_matrix = df_activos.pct_change().apply(lambda x: np.log(1+x)).corr()
corr_matrix
# Out:
# C:\ProgramData\anaconda3\Lib\site-packages\pandas\core\arraylike.py:396: RuntimeWarning: divide by zero encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# C:\ProgramData\anaconda3\Lib\site-packages\pandas\core\arraylike.py:396: RuntimeWarning: invalid value encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# ACTIVOS      CMOCTEZ.MX  CULTIBAB.MX  PASAB.MX
# ACTIVOS
# CMOCTEZ.MX          NaN          NaN       NaN
# CULTIBAB.MX         NaN          NaN       NaN
# PASAB.MX            NaN          NaN       NaN

# %%
# Randomly weighted portfolio's variance
w = {'GISSAA.MX': 0.1, 'POCHTECB.MX': 0.2, 'LIVEPOL1.MX': 0.5}
port_var = cov_matrix.mul(w, axis=0).mul(w, axis=1).sum().sum()
port_var
# Out:
# 0.0

# %%
# Yearly returns for individual companies
ind_er = df_activos.resample('Y').last().pct_change().mean()
ind_er
# Out:
# ACTIVOS
# CMOCTEZ.MX    NaN
# CULTIBAB.MX   NaN
# PASAB.MX      NaN
# dtype: float64

# %%
# Portfolio returns
w = [0.1, 0.2, 0.5]
port_er = (w*ind_er).sum()
port_er
# Out:
# 0.0

# %%
# Volatility is given by the annual standard deviation. We multiply by 250 because there are 250 trading days/year.
ann_sd = df_activos.pct_change().apply(lambda x: np.log(1+x)).std().apply(lambda x: x*np.sqrt(250))
ann_sd
# Out:
# C:\ProgramData\anaconda3\Lib\site-packages\pandas\core\arraylike.py:396: RuntimeWarning: divide by zero encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# C:\ProgramData\anaconda3\Lib\site-packages\pandas\core\arraylike.py:396: RuntimeWarning: invalid value encountered in log
#   result = getattr(ufunc, method)(*inputs, **kwargs)
# ACTIVOS
# CMOCTEZ.MX    NaN
# CULTIBAB.MX   NaN
# PASAB.MX      NaN
# dtype: float64

# %%
assets = pd.concat([ind_er, ann_sd], axis=1) # Creating a table for visualising returns and volatility of assets
assets.columns = ['Returns', 'Volatility']
assets
# Out:
#              Returns  Volatility
# ACTIVOS
# CMOCTEZ.MX       NaN         NaN
# CULTIBAB.MX      NaN         NaN
# PASAB.MX         NaN         NaN

# %%
p_ret = [] # Define an empty array for portfolio returns
p_vol = [] # Define an empty array for portfolio volatility
p_weights = [] # Define an empty array for asset weights

num_assets = len(df_activos.columns)
num_portfolios = 10000

# %%
for portfolio in range(num_portfolios):
    weights = np.random.random(num_assets)
    weights = weights/np.sum(weights)
    p_weights.append(weights)
    returns = np.dot(weights, ind_er) # Returns are the product of individual expected returns of asset and its 
                                      # weights 
    p_ret.append(returns)
    var = cov_matrix.mul(weights, axis=0).mul(weights, axis=1).sum().sum()# Portfolio Variance
    sd = np.sqrt(var) # Daily standard deviation
    ann_sd = sd*np.sqrt(250) # Annual standard deviation = volatility
    p_vol.append(ann_sd)

# %%
data = {'Returns':p_ret, 'Volatility':p_vol}

for counter, symbol in enumerate(df_activos.columns.tolist()):
    #print(counter, symbol)
    data[symbol+' weight'] = [w[counter] for w in p_weights]

# %%
portfolios  = pd.DataFrame(data)
portfolios.head() # Dataframe of the 10000 portfolios created
# Out:
#    Returns  Volatility  CMOCTEZ.MX weight  CULTIBAB.MX weight  PASAB.MX weight
# 0      NaN         0.0           0.079976            0.676072         0.243952
# 1      NaN         0.0           0.506896            0.435542         0.057562
# 2      NaN         0.0           0.347997            0.142797         0.509207
# 3      NaN         0.0           0.329374            0.297372         0.373255
# 4      NaN         0.0           0.081944            0.304295         0.613761

# %%
portfolios.plot.scatter(x='Volatility', y='Returns', marker='o', s=10, alpha=0.3, grid=True, figsize=[10,10])
# Out:
# <Axes: xlabel='Volatility', ylabel='Returns'>
